# %% [markdown]
# <a href="https://colab.research.google.com/github/nasimadnan/Artificial-Intelligence/blob/main/Nasim_ML1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset
iris = load_iris()

data = pd.DataFrame(iris.data, columns = iris.feature_names)
data['species'] = iris.target

data['cluster'] = KMeans(n_clusters = 3, n_init='auto').fit_predict(data.values)

print(data)

sns.scatterplot(data=data, x='sepal length (cm)', y='sepal width (cm)', hue='cluster', palette='viridis')
plt.title('K-means Clustering on Iris Dataset')
plt.show()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      species  cluster
# ...
